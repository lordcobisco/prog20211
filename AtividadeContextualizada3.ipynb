# %%
#Esta é apenas uma simulação de entrada de dados, não sendo aplicável em casos reais.
#a. Crie as variáveis necessárias para que o programa funcione corretamente.
#b. Inicialize as variáveis com valores padrão adequados.

resolucao = 100
velocidade = 150
digitalizacao = 200
iluminacao = 100
profundidade = 400
espessura  = 10
qualidade = 100
contrataste = 50
laser = 2
colimacao = 2 

#c. Crie uma pequena mensagem de apresentação do programa para realizar uma interface com o usuário.
print('Esse programa tem como objetivo sistematizar o processo de inicialização do microscopio confocal modelo xxx')

Nome_do_usuario = input('Para iniciar digite seu nome')

#d. Solicite algumas informações necessárias para a configuração de um microscópio dessa natureza. Buscar pelo menos 10 itens para essas informações de entrada. Ex.: resolução da imagem desejada, tipo de célula a ser escaneada, faixa de iluminação necessária. 

resolucao = input('Qual a resolução?')
print('Houve alteração na variavavél inserida?')
print(resolucao == resolucao)

velocidade = input('Qual a velocidade de captura?')
print('Houve alteração na variavavél inserida?')
print(velocidade == velocidade)

digitalizacao = input('Qual a velocidade de digitalização?')
print('Houve alteração na variavavél inserida?')
print(digitalizacao == digitalizacao)

iluminacao = input('Qual a faixa de iluminação?')
print('Houve alteração na variavavél inserida?')
print(iluminacao == iluminacao)

profundidade = input('Qual a profundidade?')
print('Houve alteração na variavavél inserida?')
print(profundidade == profundidade)

espessura = input('Qual a espessura do corte?')
print('Houve alteração na variavavél inserida?')
print(espessura == espessura)

qualidade = input('Qual a qualidade da imagem?')
print('Houve alteração na variavavél inserida?')
print(qualidade == qualidade)

contrataste = input('Qual o nível de contraste')
print('Houve alteração na variavavél inserida?')
print(contrataste == contrataste)

laser = input('Qual laser utilizado?')
print('Houve alteração na variavavél inserida?')
print(laser == laser)

colimacao = input('Qual colimação da janela?')
print('Houve alteração na variavavél inserida?')
print(colimacao == colimacao)


#f. Retorne ao usuário de forma organizada as informações que foram digitadas. Ex.: “As informações de configurações setadas pelo usuário são: ...”

print(resolucao, velocidade, digitalizacao, iluminacao, profundidade, espessura, qualidade, contrataste, laser, colimacao)

print('As informações de configurações setadas pelo usuário são')

print('A resolução selelcionada foi: %s' %(resolucao))
print('A velocidade de captura foi: %s' %(velocidade))
print('A velocidade de digitalização foi: %s' %(digitalizacao))
print('A faixa de iluminação foi: %s' %(iluminacao))
print('A profundidade da imagem foi: %s' %(profundidade))
print('A espesura do corte foi: %s' %(espessura))
print('A qualidade da imagem foi: %s' %(qualidade))
print('O contraste da imagem foi: %s' %(contrataste))
print('O laser selecionado foi: %s' %(laser))
print('A colimação da janela foi: %s' %(colimacao))

#g.apertar a tecla correspondente à primeira letra do seu nome
#h. imediatamente após apertar a tecla o programa deve apresentar na tela que a informação foi corretamente digitada e mostrar o caractere pressionado.

print('Calibração do sistema')
print('Para iniciar a calibração do sistema será necessário digitar algumas letras do seu nome, siga os comandos')
calibracao1 = input('Digite à primeira letra do seu nome, esse processo se repetirá por 10 vezes seguidas')
print(calibracao1)
print('A letra digitada foi: %s' %(calibracao1))

calibracao1 = input('Digite à primeira letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao1)
print('A letra digitada foi: %s' %(calibracao1))

calibracao1 = input('Digite à primeira letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao1)
print('A letra digitada foi: %s' %(calibracao1))

calibracao1 = input('Digite à primeira letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao1)
print('A letra digitada foi: %s' %(calibracao1))

calibracao1 = input('Digite à primeira letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao1)
print('A letra digitada foi: %s' %(calibracao1))

calibracao1 = input('Digite à primeira letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao1)
print('A letra digitada foi: %s' %(calibracao1))

calibracao1 = input('Digite à primeira letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao1)
print('A letra digitada foi: %s' %(calibracao1))

calibracao1 = input('Digite à primeira letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao1)
print('A letra digitada foi: %s' %(calibracao1))

calibracao1 = input('Digite à primeira letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao1)
print('A letra digitada foi: %s' %(calibracao1))

calibracao1 = input('Digite à primeira letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao1)
print('A letra digitada foi: %s' %(calibracao1))


#apertar a tecla correspondente à última letra do seu nome

calibracao2 = input('Digite à última letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao2)
print('A letra digitada foi: %s' %(calibracao2))

calibracao2 = input('Digite à última letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao2)
print('A letra digitada foi: %s' %(calibracao2))

calibracao2 = input('Digite à última letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao2)
print('A letra digitada foi: %s' %(calibracao2))

calibracao2 = input('Digite à última letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao2)
print('A letra digitada foi: %s' %(calibracao2))

calibracao2 = input('Digite à última letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao2)
print('A letra digitada foi: %s' %(calibracao2))

calibracao2 = input('Digite à última letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao2)
print('A letra digitada foi: %s' %(calibracao2))

calibracao2 = input('Digite à última letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao2)
print('A letra digitada foi: %s' %(calibracao2))

calibracao2 = input('Digite à última letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao2)
print('A letra digitada foi: %s' %(calibracao2))

calibracao2 = input('Digite à última letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao2)
print('A letra digitada foi: %s' %(calibracao2))

calibracao2 = input('Digite à última letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracao2)
print('A letra digitada foi: %s' %(calibracao2))

#i. Na sequência o usuário deve utilizar dois caracteres para a calibração do equipamento no sentido vertical. Para isso, ele deve apertar a tecla correspondente à segunda letra do seu nome 10x e à penúltima letra do seu nome 10x.

#segunda letra
calibracaovertical1 = input('Digite a segunda letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical1)
print('A letra digitada foi: %s' %(calibracaovertical1))

calibracaovertical1 = input('Digite a segunda letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical1 )
print('A letra digitada foi: %s' %(calibracaovertical1))

calibracaovertical1 = input('Digite a segunda letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical1 )
print('A letra digitada foi: %s' %(calibracaovertical))

calibracaovertical = input('Digite a segunda letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical )
print('A letra digitada foi: %s' %(calibracaovertical))

calibracaovertical = input('Digite a segunda letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical )
print('A letra digitada foi: %s' %(calibracaovertical))

calibracaovertical = input('Digite a segunda letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical )
print('A letra digitada foi: %s' %(calibracaovertical))

calibracaovertical = input('Digite a segunda letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical1 )
print('A letra digitada foi: %s' %(calibracaovertical))

calibracaovertical = input('Digite a segunda letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical1 )
print('A letra digitada foi: %s' %(calibracaovertical))

calibracaovertical = input('Digite a segunda letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical )
print('A letra digitada foi: %s' %(calibracaovertical))

calibracaovertical = input('Digite a segunda letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical1 )
print('A letra digitada foi: %s' %(calibracaovertical))

#penúltima letra

calibracaovertical2 = input('Digite a penúltima letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical2)
print('A letra digitada foi: %s' %(calibracaovertical2))

calibracaovertical2 = input('Digite a penúltima letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical2)
print('A letra digitada foi: %s' %(calibracaovertical2))


calibracaovertical2 = input('Digite a penúltima letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical2)
print('A letra digitada foi: %s' %(calibracaovertical2))


calibracaovertical2 = input('Digite a penúltima letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical2)
print('A letra digitada foi: %s' %(calibracaovertical2))


calibracaovertical2 = input('Digite a penúltima letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical2)
print('A letra digitada foi: %s' %(calibracaovertical2))


calibracaovertical2 = input('Digite a penúltima letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical2)
print('A letra digitada foi: %s' %(calibracaovertical2))


calibracaovertical2 = input('Digite a penúltima letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical2)
print('A letra digitada foi: %s' %(calibracaovertical2))


calibracaovertical2 = input('Digite a penúltima letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical2)
print('A letra digitada foi: %s' %(calibracaovertical2))


calibracaovertical2 = input('Digite a penúltima letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical2)
print('A letra digitada foi: %s' %(calibracaovertical2))


calibracaovertical2 = input('Digite a penúltima letra do seu nome, esse processo se repetirá por 10 vezes seguidas'')
print(calibracaovertical2)
print('A letra digitada foi: %s' %(calibracaovertical2))

print('Fim da calibração')
# Out:
# Digite à primeira letra do seu nomea
# a
# A letra digitada foi: a
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     618         """
# --> 619         parts = [self.recv(flags, copy=copy, track=track)]
# ...
